# %% [markdown]
# ### Exercise 1 : Matrix Operations
# Instructions: In this exercise, you’ll work with a 3x3 matrix. Here’s a brief explanation of the concepts:
#
# * Determinant: The determinant is a value that can be computed from the elements of a square matrix. It provides important information about the matrix, such as whether it has an inverse, and is used in various areas like linear algebra and calculus. To understand more about it you can watch this video.
# * Inverse of a Matrix: The inverse of a matrix is a matrix that, when multiplied with the original matrix, results in an identity matrix. Not all matrices have inverses. The inverse is crucial in solving systems of linear equations.
# * Create a 3x3 matrix and perform the following operations:
#
# Calculate the determinant.
# Find the inverse of the matrix.

# %%
import pandas as pd
import numpy as np

# %%
matrix = [ 
    [1 ,2 ,3], 
    [4, 3, 6,],
    [7, 8, 10]
]

det_matrix = np.linalg.det(matrix)
inv_matrix = np.linalg.inv(matrix)

print(f"Matrix Determinant: {det_matrix:.2f}")
print(f"Matrix inverse: {inv_matrix}")

# %% [markdown]
# ### Exercise 2 : Statistical Analysis
# Instructions: In this exercise, you’ll calculate statistical measures for a dataset:
#
# * Mean: The average value of a dataset.
# * Median: The middle value in a dataset when it is arranged in ascending or descending order.
# * Standard Deviation: A measure of the amount of variation or dispersion in a set of values.
# * Using NumPy, generate an array of 50 random numbers and compute:
#
#     * The mean and median.
#     * The standard deviation.

# %%
np.random.seed(50)
num_array = np.random.normal(loc=100, scale=15, size=50)

mean = np.mean(num_array).round(2)
median = np.median(num_array).round(2)
std = np.std(num_array).round(2)

print(f"The number array\nMean: {mean}\nMedian: {median}\nStd: {std}")

# %% [markdown]
# # Exercise 3 : Date Manipulation
# Instructions: Create a NumPy array of dates for the month of January 2023. Convert these dates to another format (e.g., YYYY/MM/DD).

# %%
dates_jan = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')
print(dates_jan)

formatted_jan = np.char.replace(dates_jan.astype(str), '-', '/')
print(formatted_jan)

# %% [markdown]
# ### Exercise 4 : Data Manipulation with NumPy and Pandas
# Instructions: Create a DataFrame with random numbers and perform:
#
# * Conditional selection of data.
# * Aggregation functions like sum and average.

# %%
# Create a dataframe with random numbers
np.random.seed(42)
data = np.random.randint(1,100,size=(10,3))
df = pd.DataFrame(data,columns=['A', 'B', 'C'])

# Conditional selection

# Select rows where column 'A' is greater than 50
high_a = df[df['A'] > 50]

# Aggregation functions
column_sums = df.sum()
overall_mean = df.values.mean()
print(f"Overall Mean:\n{overall_mean}")
column_mean = df.mean()
print(f"Column Mean:\n{column_mean}")
row_mean_np = np.mean(data, axis=1)
print(f"Row Means:", row_mean_np)

# %% [markdown]
# ### Exercise 5 : Image Representation
# Instructions: Explain how images are represented in NumPy arrays and demonstrate with a simple example (e.g., creating a 5x5 grayscale image).

# %% [markdown]
# Images are multidimensional arrays of numbers. Each number represents the intesity of a pixel. Grayscale images are 2D arrays. Color images are 3D arrays, with the 3rd dimensional holding 3 values for every pixel: RGB.

# %%
import matplotlib.pyplot as plt

# %%
gray_image = np.random.randint(0, 256, size=(5,5), dtype='uint8')

print("The image matrix:")
print(gray_image)

plt.imshow(gray_image, cmap='gray')
plt.title('5x5 Grayscale Image')
plt.colorbar()
plt.show()

# %% [markdown]
# ### Exercise 6 : Basic Hypothesis Testing
# Instructions: Create a sample dataset to test the effectiveness of a new training program on employee productivity:
#
# Given a dataset, formulate a simple hypothesis and test it using basic statistical functions in NumPy.

# %%
# Productivity scores of employees before the training program
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

# Your task is to formulate a hypothesis regarding the training program's effectiveness 
# and test it using basic statistical functions in NumPy.

# %% [markdown]
# 1. Null Hypothesis: The training program has no effect on employee productivity scores
# 2. Alternatve Hypothesis: The training program was effective. The mean productivity after the training program is greater than the mean productivity before the training program.

# %%
improvement = productivity_after - productivity_before

mean_improvement = np.mean(improvement)
std_improvement = np.std(std)
median_improvement = np.median(improvement)

improved_count = np.sum(improvement > 0)
percent_improved = (improved_count / len(improvement)) * 100

print(f"Mean Productivity Increase: {mean_improvement: .2f}")
print(f"Standard deviation of change: {std_improvement}")
print(f"Percent of employees who improved: {percent_improved}")

# %% [markdown]
# Because the mean increased by 4.87 points for almost 100% of employees (96.7%), we can confirm that the alternate hypothesis is true and the training program was effective.

# %% [markdown]
# ### Exercise 7 : Complex Array Comparison
# Instructions: Create two arrays and perform element-wise comparison to find which elements are greater in the first array.
#
# The expected output is a boolean array showing which elements in the first array are greater than the corresponding elements in the second array.

# %%
np.random.seed(10)

array1 = np.random.randint(1,100, size=5)
array2 = np.random.randint(1,100, size=5)

is_greater = array1 > array2
print(f"Array 1: {array1}")
print(f"Array 2: {array2}")
print(f"Is Array 1 > Array 2?\n{is_greater}")

# %% [markdown]
# ### Exercise 8 : Time Series Data Manipulation
# Instructions: Generate time series data for the year 2023. Demonstrate slicing for the following intervals:
# * January to March
# * April to June
# * July to September
# * October to December
#
# Generate a time series data for a specific period and demonstrate how to slice this data for different intervals.

# %%
dates = np.arange('2023-01-01', '2024-01-01', dtype='datetime64[D]')

np.random.seed(42)
values= np.random.randint(10,100, size=len(dates))

dtype = [('Date', 'datetime64[D]'), ('Value', 'i4')]
data = np.zeros(len(dates), dtype=dtype)
data['Date'] = dates
data['Value'] = values

jan_mar = data[(data['Date'] >= np.datetime64('2023-01-01')) & (data['Date'] <= np.datetime64('2023-03-31'))]
apr_jun = data[(data['Date'] >= np.datetime64('2023-04-01')) & (data['Date'] <= np.datetime64('2023-06-30'))]
jul_sep = data[(data['Date'] >= np.datetime64('2023-07-01')) & (data['Date'] <= np.datetime64('2023-09-30'))]
oct_dec = data[(data['Date'] >= np.datetime64('2023-10-01')) & (data['Date'] <= np.datetime64('2023-12-31'))]

# Output results
print("First 3 days of Q1 (Jan-Mar):")
print(jan_mar[:3])

print(f"\nRow Counts:\nQ1: {len(jan_mar)}\nQ2: {len(apr_jun)}\nQ3: {len(jul_sep)}\nQ4: {len(oct_dec)}")

# %% [markdown]
# ### Exercise 9 : Data Conversion
# Instructions: Demonstrate how to convert a NumPy array to a Pandas DataFrame and vice versa.

# %%
# NumPy Array to Pandas DataFrame

np_array = np.array([[10,20,30],
                     [40,50,60],
                     [70,80,90]])

# Convert np_array to df
df = pd.DataFrame(np_array, columns=['Col1', 'Col2', 'Col3'])

print("Pandas DataFrame:")
print(df)

# %%
# Pandas DataFrame to NumPy Array 

array_from_df = df.to_numpy()

print("NumPy Array from DataFrame:")
print(array_from_df)
print(f"Type: {type(array_from_df)}")

# %% [markdown]
# ### Exercise 10 : Basic Visualization
# Instructions: Use Matplotlib to visualize a simple dataset created with NumPy (e.g., a line graph of random numbers).

# %%
# Create a simple dataset with NumPy
np.random.seed(7)
x = np.arange(50) # o tp 49 for the x axis 
y = np.random.randint(10,100,50) # 50 random ints between 10 and 100 for the y-axis

# Create the plot
plt.figure(figsize=(10,5))
plt.plot(x,y,color='green', marker='o', linestyle='-', linewidth=2, markersize=4)
plt.title("Simple Random Trend (NumPy + Matplotlib)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True, alpha=0.3)

plt.show()
