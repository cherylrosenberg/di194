# %%
python # Simple Python code to display text print("Hello, Jupyter!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python # Simple Python code to display text print("Hello, Jupyter!")
#
# NameError: name 'python' is not defined

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!
